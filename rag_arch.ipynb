# %%
# !pip install langchain_google_genai
# Out:
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# ...
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# ...
#    ---------------------------------------- 0.0/984.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/984.2 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/984.2 kB ? eta -:--:--
#    --------------------- ------------------ 524.3/984.2 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 984.2/984.2 kB 1.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----------- ---------------------------- 1.0/3.8 MB 2.5 MB/s eta 0:00:02
#    ------------- -------------------------- 1.3/3.8 MB 2.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.6/3.8 MB 2.2 MB/s eta 0:00:02
# ...

# %%
# !pip show google-generativeai
# Out:
# WARNING: Package(s) not found: google-generativeai

# %%
# !pip freeze | findstr google
# Out:
# google-auth==2.55.2
# google-genai==2.11.0
# google-pasta==0.2.0
# googleapis-common-protos==1.75.0
# langchain-google-genai==4.2.7
