# %%
# !pip install torchvision
# Out:
# ...
#   Using cached setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.5 MB 1.9 MB/s eta 0:00:02
#    -------- ------------------------------- 0.8/3.5 MB 1.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.0/3.5 MB 1.4 MB/s eta 0:00:02
#    -------------- ------------------------- 1.3/3.5 MB 1.6 MB/s eta 0:00:02
#    -------------------- ------------------- 1.8/3.5 MB 1.5 MB/s eta 0:00:02
#    -------------------- ------------------- 1.8/3.5 MB 1.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 2.1/3.5 MB 1.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.6/3.5 MB 1.5 MB/s eta 0:00:01
#    -------------------------------- ------- 2.9/3.5 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.1/3.5 MB 1.4 MB/s eta 0:00:01
# ...
